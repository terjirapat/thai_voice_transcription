# %%
import speech_recognition as sr

# %%
r = sr.Recognizer()

# %%
with sr.Microphone() as source:
    # print("Please wait. Calibrating microphone...")
    # r.adjust_for_ambient_noise(source, duration=5)
    # print("Microphone calibrated")
    print("Say something!")
    audio = r.listen(source)
    text = r.recognize_google(audio, language="th-TH")
    print("You said: " + text)
# Out:
# Say something!
# You said: สวัสดีผมชื่อเต๋อ

# %%
with sr.Microphone() as source:
    while True:
        audio = r.listen(source)
        text = r.recognize_google(audio, language="th-TH")
        print("You said: " + text)
# Out:
# You said: สวัสดีผมชื่อเต๋อตอนนี้ที่กรุงเทพฯฝนตกหนักมากและตอนนี้เป็นเวลาเที่ยงคืนครึ่ง
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 3
#       1 with sr.Microphone() as source:
#       2     while True:
# ----> 3         audio = r.listen(source)
#       4         text = r.recognize_google(audio, language="th-TH")
#       5         print("You said: " + text)
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\speech_recognition\__init__.py:460, in Recognizer.listen(self, source, timeout, phrase_time_limit, snowboy_configuration, stream)
#     458 result = self._listen(source, timeout, phrase_time_limit, snowboy_configuration, stream)
#     459 if not stream:
# --> 460     for a in result:
#     461         return a
#     462 return result
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\speech_recognition\__init__.py:530, in Recognizer._listen(self, source, timeout, phrase_time_limit, snowboy_configuration, stream)
#     527 if phrase_time_limit and elapsed_time - phrase_start_time > phrase_time_limit:
#     528     break
# --> 530 buffer = source.stream.read(source.CHUNK)
#     531 if len(buffer) == 0: break  # reached end of the stream
#     532 frames.append(buffer)
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\speech_recognition\__init__.py:191, in Microphone.MicrophoneStream.read(self, size)
#     190 def read(self, size):
# --> 191     return self.pyaudio_stream.read(size, exception_on_overflow=False)
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\pyaudio\__init__.py:570, in PyAudio.Stream.read(self, num_frames, exception_on_overflow)
#     567 if not self._is_input:
#     568     raise IOError("Not input stream",
#     569                   paCanNotReadFromAnOutputOnlyStream)
# --> 570 return pa.read_stream(self._stream, num_frames,
#     571                       exception_on_overflow)
#
# KeyboardInterrupt:
