# %%
import sounddevice as sd
import numpy as np

SAMPLE_RATE = 16000
BLOCK_SIZE = 1024  # samples per callback

def audio_callback(indata, frames, time, status):
    if status:
        print(status)
    audio_block = indata[:, 0]  # mono
    # ส่ง audio_block ไปยังโมเดล ASR ได้ทันที
    print("Audio block:", audio_block[:5])

print("🎤 Start capturing (Ctrl+C to stop)")
with sd.InputStream(samplerate=SAMPLE_RATE, channels=1, dtype="float32",
                    blocksize=BLOCK_SIZE, callback=audio_callback):
    while True:
        sd.sleep(100)
# Out:
# 🎤 Start capturing (Ctrl+C to stop)
# Audio block: [0.00241089 0.00546265 0.00521851 0.00485229 0.0043335 ]
# Audio block: [0.00054932 0.00082397 0.00125122 0.00158691 0.00137329]
# Audio block: [0.00216675 0.00140381 0.0012207  0.00189209 0.00161743]
# Audio block: [-7.6293945e-04 -6.1035156e-05 -6.7138672e-04 -6.1035156e-04
#  -8.2397461e-04]
# Audio block: [-6.7138672e-04 -3.6621094e-04 -3.3569336e-04  6.1035156e-05
#  -3.3569336e-04]
# Audio block: [0.00302124 0.00186157 0.00222778 0.00219727 0.00228882]
# Audio block: [-0.003479   -0.00387573 -0.00372314 -0.00390625 -0.00445557]
# Audio block: [-0.00073242 -0.00042725 -0.00027466 -0.00079346 -0.00033569]
# Audio block: [-0.00119019 -0.00048828 -0.00161743 -0.00097656 -0.00134277]
# Audio block: [0.00036621 0.0007019  0.00045776 0.00054932 0.00085449]
# Audio block: [0.00213623 0.00158691 0.00131226 0.0015564  0.00177002]
# Audio block: [-0.00061035 -0.00064087 -0.00149536 -0.00097656 -0.00100708]
# Audio block: [0.00115967 0.00137329 0.00106812 0.00073242 0.0012207 ]
# Audio block: [-2.7465820e-04 -4.5776367e-04  9.1552734e-05 -6.1035156e-04
#  -2.4414062e-04]
# Audio block: [-9.1552734e-05 -3.3569336e-04  2.4414062e-04 -8.5449219e-04
#  -6.7138672e-04]
# Audio block: [3.6621094e-04 0.0000000e+00 8.2397461e-04 3.3569336e-04 6.1035156e-05]
# Audio block: [ 0.         -0.00064087 -0.00045776 -0.00064087 -0.00094604]
# Audio block: [-0.00064087 -0.00042725 -0.00067139 -0.00036621 -0.00061035]
# Audio block: [9.1552734e-05 9.1552734e-04 1.5258789e-04 5.7983398e-04 0.0000000e+00]
# Audio block: [-0.00128174 -0.00131226 -0.00106812 -0.00094604 -0.00112915]
# Audio block: [ 1.8310547e-04  4.2724609e-04 -3.0517578e-05  5.1879883e-04
#   1.2207031e-04]
# Audio block: [-0.00015259  0.00015259  0.00024414  0.00054932  0.00024414]
# Audio block: [ 3.0517578e-05  5.1879883e-04 -6.1035156e-05 -6.7138672e-04
#  -1.2207031e-04]
# Audio block: [0.00045776 0.00079346 0.00106812 0.00012207 0.00015259]
# Audio block: [0.00045776 0.00076294 0.00033569 0.00030518 0.00015259]
# Audio block: [ 2.7465820e-04 -9.1552734e-05 -3.0517578e-04 -3.6621094e-04
#  -5.1879883e-04]
# Audio block: [-0.00048828 -0.00030518 -0.00033569 -0.00067139 -0.00061035]
# Audio block: [0.00064087 0.00039673 0.0005188  0.00115967 0.00015259]
# Audio block: [-6.1035156e-05  6.1035156e-05 -3.0517578e-04 -5.4931641e-04
#  -5.1879883e-04]
# Audio block: [ 0.00057983 -0.00012207  0.00057983 -0.00021362  0.00030518]
# Audio block: [ 0.0000000e+00 -1.5258789e-04 -2.4414062e-04 -2.1362305e-04
#  -3.0517578e-05]
# Audio block: [-0.0010376  -0.00128174 -0.00054932 -0.00082397 -0.00082397]
# Audio block: [-0.00079346  0.00192261  0.00030518  0.00057983 -0.00018311]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 18
#      15 with sd.InputStream(samplerate=SAMPLE_RATE, channels=1, dtype="float32",
#      16                     blocksize=BLOCK_SIZE, callback=audio_callback):
#      17     while True:
# ---> 18         sd.sleep(100)
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\sounddevice.py:712, in sleep(msec)
#     705 def sleep(msec):
#     706     """Put the caller to sleep for at least *msec* milliseconds.
#     707
#     708     The function may sleep longer than requested so don't rely on this
#     709     for accurate musical timing.
#     710
#     711     """
# --> 712     _lib.Pa_Sleep(msec)
#
# KeyboardInterrupt:

# %%
import signal

if not hasattr(signal, "SIGKILL"):
    signal.SIGKILL = signal.SIGTERM

# %%
import numpy as np
from typhoon_asr import transcribe
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 from typhoon_asr import transcribe
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\typhoon_asr\__init__.py:5
#       3 import time
#       4 from pathlib import Path
# ----> 5 import nemo.collections.asr as nemo_asr
#       6 import torch
#       7 import librosa
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\nemo\collections\asr\__init__.py:15
#       1 # Copyright (c) 2020, NVIDIA CORPORATION.  All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 15 from nemo.collections.asr import data, losses, models, modules
#      16 from nemo.package_info import __version__
#      18 # Set collection version equal to NeMo version.
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\nemo\collections\asr\losses\__init__.py:15
#       1 # Copyright (c) 2020, NVIDIA CORPORATION.  All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 15 from nemo.collections.asr.losses.angularloss import AngularSoftmaxLoss
#      16 from nemo.collections.asr.losses.bce_loss import BCELoss
#      17 from nemo.collections.asr.losses.ctc import CTCLoss
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\nemo\collections\asr\losses\angularloss.py:18
#       1 # ! /usr/bin/python
#       2 # Copyright (c) 2020, NVIDIA CORPORATION.  All rights reserved.
#       3 #
#    (...)
#      13 # See the License for the specific language governing permissions and
#      14 # limitations under the License.
#      16 import torch
# ---> 18 from nemo.core.classes import Loss, Typing, typecheck
#      19 from nemo.core.neural_types import LabelsType, LogitsType, LossType, NeuralType
#      21 __all__ = ['AngularSoftmaxLoss']
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\nemo\core\__init__.py:16
#       1 # Copyright (c) 2020, NVIDIA CORPORATION.  All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 import nemo.core.neural_types
# ---> 16 from nemo.core.classes import *
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\nemo\core\classes\__init__.py:17
#       1 # Copyright (c) 2020, NVIDIA CORPORATION.  All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      16 import hydra
# ---> 17 import lightning.pytorch
#      18 import omegaconf
#      20 from nemo.core.classes.common import (
#      21     FileIO,
#      22     Model,
#    (...)
#      27     typecheck,
#      28 )
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\lightning\__init__.py:18
#      16 from lightning.__about__ import *  # noqa: E402, F403
#      17 from lightning.__version__ import version as __version__  # noqa: E402
# ---> 18 from lightning.fabric.fabric import Fabric  # noqa: E402
#      19 from lightning.fabric.utilities.seed import seed_everything  # noqa: E402
#      20 from lightning.pytorch.callbacks import Callback  # noqa: E402
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\lightning\fabric\__init__.py:30
#      24 # Setting this variable will force `torch.cuda.is_available()` and `torch.cuda.device_count()`
#      25 # to use an NVML-based implementation that doesn't poison forks.
#      26 # https://github.com/pytorch/pytorch/issues/83973
#      27 os.environ["PYTORCH_NVML_BASED_CUDA_CHECK"] = "1"
# ---> 30 from lightning.fabric.fabric import Fabric  # noqa: E402
#      31 from lightning.fabric.utilities.seed import seed_everything  # noqa: E402
#      32 from lightning.fabric.utilities.warnings import disable_possible_user_warnings  # noqa: E402
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\lightning\fabric\fabric.py:44
#      41 from torch.utils.data import BatchSampler, DataLoader, DistributedSampler, RandomSampler, SequentialSampler
#      43 import lightning.fabric
# ---> 44 from lightning.fabric.accelerators.accelerator import Accelerator
#      45 from lightning.fabric.connector import _PLUGIN_INPUT, _PRECISION_INPUT, _Connector, _is_using_cli
#      46 from lightning.fabric.loggers import Logger
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\lightning\fabric\accelerators\__init__.py:15
#       1 # Copyright The Lightning AI team.
#       2 # Licensed under the Apache License, Version 2.0 (the "License");
#       3 # you may not use this file except in compliance with the License.
#    (...)
#      11 # See the License for the specific language governing permissions and
#      12 # limitations under the License.
#      13 import sys
# ---> 15 from lightning.fabric.accelerators.accelerator import Accelerator
#      16 from lightning.fabric.accelerators.cpu import CPUAccelerator  # noqa: F401
#      17 from lightning.fabric.accelerators.cuda import CUDAAccelerator, find_usable_cuda_devices  # noqa: F401
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\lightning\fabric\accelerators\accelerator.py:19
#      15 from typing import Any
#      17 import torch
# ---> 19 from lightning.fabric.accelerators.registry import _AcceleratorRegistry
#      22 class Accelerator(ABC):
#      23     """The Accelerator base class.
#      24
#      25     An Accelerator is meant to deal with one type of hardware.
#    (...)
#      28
#      29     """
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\lightning\fabric\accelerators\registry.py:18
#      14 from typing import Any, Callable, Dict, List, Optional
#      16 from typing_extensions import override
# ---> 18 from lightning.fabric.utilities.exceptions import MisconfigurationException
#      19 from lightning.fabric.utilities.registry import _register_classes
#      22 class _AcceleratorRegistry(dict):
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\lightning\fabric\utilities\__init__.py:16
#       1 # Copyright The Lightning AI team.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      14 """General utilities."""
# ---> 16 from lightning.fabric.utilities.apply_func import move_data_to_device
#      17 from lightning.fabric.utilities.data import AttributeDict, suggested_max_num_workers
#      18 from lightning.fabric.utilities.distributed import is_shared_filesystem
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\lightning\fabric\utilities\apply_func.py:44
#      34     return torch.from_numpy(value).to(device)
#      37 CONVERSION_DTYPES: List[Tuple[Any, Callable[[Any, Any], Tensor]]] = [
#      38     # bool -> uint8 as bool -> torch.bool triggers RuntimeError: Unsupported data type for NCCL process group
#      39     (bool, partial(torch.tensor, dtype=torch.uint8)),
#      40     (int, partial(torch.tensor, dtype=torch.int)),
#      41     (float, partial(torch.tensor, dtype=torch.float)),
#      42 ]
# ---> 44 if _NUMPY_AVAILABLE:
#      45     import numpy as np
#      47     CONVERSION_DTYPES.append((np.ndarray, _from_numpy))
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\lightning_utilities\core\imports.py:200, in RequirementCache.__bool__(self)
#     198 def __bool__(self) -> bool:
#     199     """Format as bool."""
# --> 200     self._check_available()
#     201     return self.available
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\lightning_utilities\core\imports.py:166, in RequirementCache._check_available(self)
#     164     return
#     165 if self.requirement:
# --> 166     self._check_requirement()
#     167 if getattr(self, "available", True) and self.module:
#     168     self._check_module()
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\lightning_utilities\core\imports.py:131, in RequirementCache._check_requirement(self)
#     129 try:
#     130     req = Requirement(self.requirement)
# --> 131     pkg_version = Version(_version(req.name))
#     132     self.available = req.specifier.contains(pkg_version, prereleases=True) and (
#     133         not req.extras or self._check_extras_available(req)
#     134     )
#     135 except (PackageNotFoundError, InvalidVersion) as ex:
#
# File d:\Git\thai_voice_transcription\.venv\lib\site-packages\packaging\version.py:200, in Version.__init__(self, version)
#     189 """Initialize a Version object.
#     190
#     191 :param version:
#    (...)
#     196     exception will be raised.
#     197 """
#     199 # Validate the version and parse it into pieces
# --> 200 match = self._regex.search(version)
#     201 if not match:
#     202     raise InvalidVersion(f"Invalid version: {version!r}")
#
# TypeError: expected string or bytes-like object

# %%
# Basic transcription
result = transcribe("audio/recorded_audio.wav")
print(result['text'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Basic transcription
# ----> 2 result = transcribe("audio/recorded_audio.wav")
#       3 print(result['text'])
#
# NameError: name 'transcribe' is not defined
